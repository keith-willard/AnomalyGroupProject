# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
x=[.1, .5, .75, .9, 1, 1.25, 1.5, 2]
y_aoc_pr_sup=[1,
0.9905,
0.7268,
0.6739,
0.7497,
0.9245,
0.999,
1
]

y_aoc_pr_unsup=[1,
0.7231,
0.6897,
0.6486,
0.7503,
0.8672,
0.9543,
1
]
sns.set(rc={'figure.figsize':(10,10)})
fig = plt.figure()
plt.plot(x, y_aoc_pr_sup)
plt.plot(x, y_aoc_pr_unsup)
fig.suptitle('AOC-PR for supervised and semi-supervised for scaled mean vector', fontsize=20)
plt.xlabel('scaled mean', fontsize=18)
plt.ylabel('AOC-PR', fontsize=16)
plt.show()
plt.savefig("credit_card_fraud_synthetic_aoc_pr_results.png")
